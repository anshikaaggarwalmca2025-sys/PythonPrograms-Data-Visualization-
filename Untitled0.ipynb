# %% [markdown]
# <a href="https://colab.research.google.com/github/anshikaaggarwalmca2025-sys/PythonPrograms-Data-Visualization-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df=pd.read_excel("/content/employee_dataset_5000_records.xlsx")

# %%
#to print data
print(df)
# Out:
#      Employee_ID           Name  Department                      Email  \
# 0          E3331  Kavita Mishra          IT  kavita.mishra@company.com
# 1          E1054     Neha Gupta          HR     neha.gupta@company.com
# 2          E3518   Sneha Kapoor          IT   sneha.kapoor@company.com
# 3          E5090    Priya Singh  Operations    priya.singh@company.com
# 4          E2202    Priya Singh  Operations    priya.singh@company.com
# ...          ...            ...         ...                        ...
# 4995       E5105  Rohit Agarwal     Finance  rohit.agarwal@company.com
# 4996       E3863       Riya Das  Operations       riya.das@company.com
# 4997       E4828  Rohit Agarwal       Sales  rohit.agarwal@company.com
# 4998       E4204  Kavita Mishra          HR  kavita.mishra@company.com
# 4999       E1374     Ankit Jain   Marketing     ankit.jain@company.com
#
#         Salary   Join_Date
# 0     119001.0  2023-04-16
# 1      96408.0  2015-07-16
# 2      27678.0  2019-12-16
# ...

# %%
# Display first 5 rows of the dataset
df.head(10)
# Out:
#   Employee_ID           Name  Department                      Email    Salary  \
# 0       E3331  Kavita Mishra          IT  kavita.mishra@company.com  119001.0
# 1       E1054     Neha Gupta          HR     neha.gupta@company.com   96408.0
# 2       E3518   Sneha Kapoor          IT   sneha.kapoor@company.com   27678.0
# 3       E5090    Priya Singh  Operations    priya.singh@company.com   52603.0
# 4       E2202    Priya Singh  Operations    priya.singh@company.com  110177.0
# 5       E4322  Rohit Agarwal       Sales  rohit.agarwal@company.com   53857.0
# 6       E3482     Neha Gupta     Finance     neha.gupta@company.com   61529.0
# 7       E1859  Rohit Agarwal       Sales  rohit.agarwal@company.com   98330.0
# 8       E4948   Sneha Kapoor     Finance   sneha.kapoor@company.com   60752.0
# 9       E1662    Rahul Verma       Sales    rahul.verma@company.com   73548.0
#
#     Join_Date
# 0  2023-04-16
# 1  2015-07-16
# 2  2019-12-16
# 3  2015-12-09
# 4  2023-03-24
# 5  2020-12-09
# ...

# %%
#to get last 5 records
df.tail()
# Out:
#      Employee_ID           Name  Department                      Email  \
# 4995       E5105  Rohit Agarwal     Finance  rohit.agarwal@company.com
# 4996       E3863       Riya Das  Operations       riya.das@company.com
# 4997       E4828  Rohit Agarwal       Sales  rohit.agarwal@company.com
# 4998       E4204  Kavita Mishra          HR  kavita.mishra@company.com
# 4999       E1374     Ankit Jain   Marketing     ankit.jain@company.com
#
#         Salary   Join_Date
# 4995   84003.0  2021-08-21
# 4996   59880.0  2023-03-15
# 4997  114478.0         NaN
# 4998  113683.0  2023-06-20
# 4999   64044.0  2018-06-09

# %%
#display random 10 records
df.sample(10)
# Out:
#      Employee_ID           Name  Department                      Email  \
# 81         E3383    Amit Sharma       Sales    amit.sharma@company.com
# 3913       E1731       Riya Das     Finance       riya.das@company.com
# 4652       E3377     Ankit Jain   Marketing     ankit.jain@company.com
# 3054       E3660   Sneha Kapoor  Operations   sneha.kapoor@company.com
# 4763       E3243     Ankit Jain   Marketing     ankit.jain@company.com
# 434        E4637       Riya Das   Marketing       riya.das@company.com
# 2858       E4751  Kavita Mishra   Marketing  kavita.mishra@company.com
# 240        E3312    Priya Singh          HR    priya.singh@company.com
# 4247       E4896   Sneha Kapoor          IT   sneha.kapoor@company.com
# 1482       E4208  Kavita Mishra   Marketing  kavita.mishra@company.com
#
#         Salary   Join_Date
# 81     65211.0  2016-10-01
# 3913   78593.0  2024-06-11
# 4652  119280.0  2017-09-24
# 3054   69385.0  2022-12-03
# 4763  111247.0  2024-11-14
# ...

# %%
#summary of records
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 6 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Employee_ID  4962 non-null   object
#  1   Name         4965 non-null   object
#  2   Department   4968 non-null   object
#  3   Email        4963 non-null   object
#  4   Salary       4973 non-null   float64
#  5   Join_Date    4962 non-null   object
# dtypes: float64(1), object(5)
# memory usage: 234.5+ KB

# %%
#statistical summary
df.describe()
# Out:
#               Salary
# count    4973.000000
# mean    72744.700583
# std     27508.215480
# min     25004.000000
# 25%     49096.000000
# 50%     73150.000000
# 75%     96650.000000
# max    119965.000000

# %%
#rename columns
df.rename
# Out:
# <bound method DataFrame.rename of      Employee_ID           Name  Department                      Email  \
# 0          E3331  Kavita Mishra          IT  kavita.mishra@company.com
# 1          E1054     Neha Gupta          HR     neha.gupta@company.com
# 2          E3518   Sneha Kapoor          IT   sneha.kapoor@company.com
# 3          E5090    Priya Singh  Operations    priya.singh@company.com
# 4          E2202    Priya Singh  Operations    priya.singh@company.com
# ...          ...            ...         ...                        ...
# 4995       E5105  Rohit Agarwal     Finance  rohit.agarwal@company.com
# 4996       E3863       Riya Das  Operations       riya.das@company.com
# 4997       E4828  Rohit Agarwal       Sales  rohit.agarwal@company.com
# 4998       E4204  Kavita Mishra          HR  kavita.mishra@company.com
# 4999       E1374     Ankit Jain   Marketing     ankit.jain@company.com
#
#         Salary   Join_Date
# 0     119001.0  2023-04-16
# ...

# %%
#to detect missing values
df.isnull()
# Out:
#       Employee_ID   Name  Department  Email  Salary  Join_Date
# 0           False  False       False  False   False      False
# 1           False  False       False  False   False      False
# 2           False  False       False  False   False      False
# 3           False  False       False  False   False      False
# 4           False  False       False  False   False      False
# ...           ...    ...         ...    ...     ...        ...
# 4995        False  False       False  False   False      False
# 4996        False  False       False  False   False      False
# 4997        False  False       False  False   False       True
# 4998        False  False       False  False   False      False
# 4999        False  False       False  False   False      False
#
# [5000 rows x 6 columns]

# %%
#to detect opposite of isnull
df.notnull()
# Out:
#       Employee_ID  Name  Department  Email  Salary  Join_Date
# 0            True  True        True   True    True       True
# 1            True  True        True   True    True       True
# 2            True  True        True   True    True       True
# 3            True  True        True   True    True       True
# 4            True  True        True   True    True       True
# ...           ...   ...         ...    ...     ...        ...
# 4995         True  True        True   True    True       True
# 4996         True  True        True   True    True       True
# 4997         True  True        True   True    True      False
# 4998         True  True        True   True    True       True
# 4999         True  True        True   True    True       True
#
# [5000 rows x 6 columns]

# %%
#to detect total missing values
df.isnull().sum()
# Out:
# Employee_ID    38
# Name           35
# Department     32
# Email          37
# Salary         27
# Join_Date      38
# dtype: int64

# %%
#df.value_counts()
# Out:
# Employee_ID  Name           Department  Email                      Salary    Join_Date
# E5500        Riya Das       HR          riya.das@company.com       76657.0   2024-05-11    1
# E1001        Priya Singh    Marketing   priya.singh@company.com    77407.0   2021-06-24    1
# E1002        Neha Gupta     Marketing   neha.gupta@company.com     53493.0   2024-08-18    1
# E1003        Arjun Nair     Sales       arjun.nair@company.com     66346.0   2024-03-22    1
#              Rohit Agarwal  Marketing   rohit.agarwal@company.com  33784.0   2024-12-19    1
#                                                                                           ..
# E1016        Neha Gupta     IT          neha.gupta@company.com     76650.0   2021-03-09    1
# E1015        Priya Singh    Sales       priya.singh@company.com    94432.0   2017-12-25    1
# E1014        Vikas Yadav    Sales       vikas.yadav@company.com    108430.0  2015-08-08    1
# ...
